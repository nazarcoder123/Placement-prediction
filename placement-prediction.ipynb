# %% [markdown]
# <a href="https://www.kaggle.com/code/nazarmohammed/placement-prediction?scriptVersionId=115932056" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/placement1/placement1.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
# This will neglate the unnamed:0 as mention in the table
df.iloc[:,1:]
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
# This will give the info about each and every column of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
# To plot the scatter plot we use required libraries
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

# %%
# To draw the scatter between both independent variable
plt.scatter(df['cgpa'],df['iq'])

# %%
# To see the placement in the scatter we add color to it
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
# Now we need to import logistic Regression for that we are using here two indepandent variable x,y

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#     Unnamed: 0  cgpa
# 0            0   6.8
# 1            1   5.9
# 2            2   5.3
# 3            3   7.4
# 4            4   5.8
# ..         ...   ...
# 95          95   4.3
# 96          96   4.4
# 97          97   6.7
# 98          98   6.3
# 99          99   6.2
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
# This will return the shape of x how much Row's & Column's it contain
x.shape
# Out:
# (100, 2)

# %%
# This will return the shape of y how much Row's & Column's it contain(In this we have only column's)
y.shape
# Out:
# (100,)

# %%
# This is the library we are impoting for training the data,testing and spliting the data
from sklearn.model_selection import train_test_split

# %%
# In this we are assigning the 10% of the data for testing purposes
train_test_split(x,y,test_size=0.1)
# Out:
# [    Unnamed: 0  cgpa
#  55          55   7.8
#  80          80   4.9
#  70          70   6.3
#  95          95   4.3
#  64          64   7.0
#  ..         ...   ...
#  53          53   8.3
#  37          37   8.1
#  28          28   5.2
#  94          94   4.7
#  40          40   4.9
#
#  [90 rows x 2 columns],
#      Unnamed: 0  cgpa
#  10          10   6.0
#  67          67   5.0
#  4            4   5.8
#  31          31   3.9
#  76          76   4.9
#  20          20   6.6
#  58          58   8.0
#  79          79   6.5
#  93          93   6.8
#  33          33   6.0,
#  55    1
#  80    0
#  70    1
#  95    0
#  64    1
#       ..
#  53    1
#  37    1
#  28    0
#  94    0
#  40    0
#  Name: placement, Length: 90, dtype: int64,
#  10    1
#  67    0
#  4     0
#  31    0
#  76    0
#  20    1
#  58    1
#  79    1
#  93    1
#  33    0
#  Name: placement, dtype: int64]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
y_test
# Out:
# 30    1
# 38    1
# 12    0
# 79    1
# 78    0
# 86    0
# 70    1
# 69    1
# 87    1
# 26    1
# Name: placement, dtype: int64

# %%
x_test
# Out:
#     Unnamed: 0  cgpa
# 30          30   7.6
# 38          38   6.5
# 12          12   5.4
# 79          79   6.5
# 78          78   6.1
# 86          86   5.1
# 70          70   6.3
# 69          69   8.5
# 87          87   5.7
# 26          26   7.0

# %%
# Now let's do scaling between -1 & +1
from sklearn.preprocessing import StandardScaler

# %%
Scaler = StandardScaler()
x_train = Scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.84171158, -0.90836264],
#        [ 0.94524786, -0.90836264],
#        [-1.09096558, -2.30883608],
#        [ 0.25500601,  0.14199245],
#        [-0.88389303, -1.08342182],
#        [-1.36706232, -0.73330346],
#        [-0.71133257, -0.64577387],
#        [-0.50426001, -0.99589223],
#        [ 0.63463903, -0.82083305],
#        [ 0.7726874 ,  0.14199245],
#        [-1.43608651, -0.82083305],
#        [-0.67682048,  0.92975876],
#        [ 1.46292924,  1.36740671],
#        [ 0.11695765,  0.92975876],
#        [-0.124627  ,  0.05446286],
#        [ 0.08244555, -0.99589223],
#        [-0.33169955, -1.17095141],
#        [-0.60779629, -1.78365854],
#        [-0.26267537, -0.47071468],
#        [-1.40157441,  0.14199245],
#        [ 0.80719949,  1.19234753],
#        [-1.05645349, -1.69612895],
#        [ 0.01342137, -0.47071468],
#        [ 0.39305438,  0.84222917],
#        [-0.43523583, -0.20812591],
#        [-0.15913909,  1.36740671],
#        [-0.81486884, -0.82083305],
# ...

# %%
x_test  = Scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-0.64230838,  1.4549363 ],
#        [-0.36621165,  0.49211081],
#        [-1.26352604, -0.47071468],
#        [ 1.04878414,  0.49211081],
#        [ 1.01427204,  0.14199245],
#        [ 1.29036878, -0.73330346],
#        [ 0.73817531,  0.31705163],
#        [ 0.70366321,  2.24270261],
#        [ 1.32488087, -0.20812591],
#        [-0.78035675,  0.92975876]])

# %%
# To train the model we have dedicated to call LogisticRegression classifier
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# Now we need to fit the x_train & y_train data set in this
# Model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# This will display the prediction of the x_test which is done by your model
clf.predict(x_test)
# Out:
# array([1, 1, 0, 1, 1, 0, 1, 1, 0, 1])

# %%
# This will give the actual result of the placement data
y_test
# Out:
# 30    1
# 38    1
# 12    0
# 79    1
# 78    0
# 86    0
# 70    1
# 69    1
# 87    1
# 26    1
# Name: placement, dtype: int64

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 30    1
# 38    1
# 12    0
# 79    1
# 78    0
# 86    0
# 70    1
# 69    1
# 87    1
# 26    1
# Name: placement, dtype: int64

# %%
# To measure the accuracy of the model we import this model
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8

# %%
# To know the relation between the column's and what type of relationship is discovered by your mode can
# be seen through

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values, clf=clf, legend=2)
# Out:
# <AxesSubplot:>

# %%
# This library convert py to file
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
